# %%
# ! pip install pygame --user

import numpy as np
import pygame 
import sys




board = {1: ' ', 2: ' ', 3: ' ',
         4: ' ', 5: ' ', 6: ' ',
         7: ' ', 8: ' ', 9: ' '}





def printBoard(board):
    print(board[1] + '|' + board[2] + '|' + board[3])
    print('-+-+-')
    print(board[4] + '|' + board[5] + '|' + board[6])
    print('-+-+-')
    print(board[7] + '|' + board[8] + '|' + board[9])
    print("\n")


def spaceIsFree(position):
    if board[position] == ' ':
        return True
    else:
        return False



def checkForWin():
    if (board[1] == board[2] and board[1] == board[3] and board[1] != ' '):
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] != ' '):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] != ' '):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] != ' '):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] != ' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False


def checkWhichMarkWon(mark):
    if board[1] == board[2] and board[1] == board[3] and board[1] == mark:
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] == mark):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] == mark):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] == mark):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] == mark):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] == mark):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] == mark):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] == mark):
        return True
    else:
        return False


def checkDraw():
    for key in board.keys():
        if (board[key] == ' '):
            return False
    return True


def playerMove():
    position = int(input("Enter the position for 'O':  "))
    #insertLetter(player, position)
    return


def compMove():
    bestScore = -800
    bestMove = 0
    for key in board.keys():
        if (board[key] == ' '):
            board[key] = bot
            score = minimax(board, 0, False)
            board[key] = ' '
            if (score > bestScore):
                bestScore = score
                bestMove = key

    #insertLetter(bot, bestMove)
    return bestMove


memo = dict() 
def get_states( board, player) :
    strs = ''
    if player :
        player = '1'
    else :
        player = '0'
   # print(board)
    for k in board.keys():
        strs = strs + board[k] if isinstance(board[k],str) else ' '
    return player + strs
   # print(player + strs)    

def minimax(board, depth, isMaximizing):
    if (checkWhichMarkWon(bot)):
        return 1
    elif (checkWhichMarkWon(player)):
        return -1
    elif (checkDraw()):
        return 0
    elif get_states(board, isMaximizing) in memo.keys():
        return memo[get_states(board, isMaximizing)]
    
   # print(memo)
    if (isMaximizing):
        bestScore = -800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = bot
                score = minimax(board, depth + 1, False)
                board[key] = ' '
                if (score > bestScore):
                    bestScore = score
        memo[get_states(board, isMaximizing)] = bestScore
        return bestScore

    else:
        bestScore = 800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = player
                score = minimax(board, depth + 1, True)
                board[key] = ' '
                if (score < bestScore):
                    bestScore = score
        memo[get_states(board, isMaximizing)] = bestScore
        return bestScore




def updata_and_returnmax( ):
    for i in range(3):
        for j in range(3):
            if board1[i,j] == 0 :
                board[i*3 + j +1] = ' '
            if board1[i,j] == 1 :
                board[i*3 + j +1] = 'O'
            if board1[i,j] == 2 :
                board[i*3 + j +1] = 'X'
    bm = compMove() -1 
    return bm // 3 , bm % 3 

player = 'O'
bot = 'X'

#------------------------------------------------------------------------------------------------------------------------#

pygame.init()

width=600
height=600
line_width=15
rows=3
cols=3
circle_redius=60
circle_width=15
cross_width=25
space=55


circle_color=(239,231,200)
red=(255,0,0)
bg_color=(66,66,66)
line_color=(23,130,130)
cross_color=(0,254,0)

screen=pygame.display.set_mode((width,height))
pygame.display.set_caption("Tic Tac Toc")
screen.fill(bg_color)


board1=np.zeros((rows,cols))
# print(board)



def draw_lines():
    
    pygame.draw.line(screen,line_color,(0,200),(600,200),line_width)
    pygame.draw.line(screen,line_color,(0,400),(600,400),line_width)
    
    pygame.draw.line(screen,line_color,(200,0),(200,600),line_width)
    pygame.draw.line(screen,line_color,(400,0),(400,600),line_width)

    
    
def draw_figures():
    for row in range(rows):
        for col in range(cols):
            if board1[row][col]==1:
                pygame.draw.circle(screen,circle_color,(int(col*200+100),int(row*200+100)),circle_redius,circle_width)
            if board1[row][col]==2:
                pygame.draw.line(screen,cross_color,(col*200+space,row*200+200-space),(col*200+200-space,row*200+space),cross_width)
                pygame.draw.line(screen,cross_color,(col*200+space,row*200+space),(col*200+200-space,row*200+200-space),cross_width)


                
                
def mark_square(row,col,player):
    board1[row][col]=player
def available_square(row,col):
    return board1[row][col]==0
def is_board_full():
    for row in range(rows):
        for col in range(cols):
            if board1[row][col]==0:
                return False
    return True 


def chick_win(player):
    
#winner vertical player    
    for col in range(cols):
        if board1[0][col]==player and board1[1][col]==player and  board1[2][col]==player :
            draw_vertical_winner(col,player)
            return True 
#winner horizental player        
    for row in range(rows):
        if board1[row][0]==player and board1[row][1] ==player and board1[row][2]== player:
            draw_horizental_winner(row,player)
            return True 
        
#winner asc diagonal player  

    if board1[2][0]==player and board1[1][1]==player and board1[0][2]==player:
        draw_asc_diagonal_winner(player)
        return True
    
#winner desc diagonal player        
    
    if board1[0][0]==player and board1[1][1]==player and board1[2][2]==player:
        draw_desc_diagonal_winner(player)
        return True
    return False
    
            
def draw_vertical_winner(col,player):
    posx=col*200+100
    if player==1:
        color= circle_color
    elif player==2:
        color=cross_color
        
        
    pygame.draw.line(screen,color,(posx,15),(posx,height-15),15)    





def draw_horizental_winner(row,player):
    posy=row*200+100
    if player==1:
        color= circle_color
    elif player==2:
        color=cross_color
        
        
    pygame.draw.line(screen,color,(15,posy),(width-15,posy),15)
    
    

def draw_asc_diagonal_winner(player):
    if player==1:
        color= circle_color
    elif player==2:
        color=cross_color
    pygame.draw.line(screen,color,(15,height-15),(width-15,15),15)    
def draw_desc_diagonal_winner(player):
    if player==1:
        color= circle_color
    elif player==2:
        color=cross_color
    pygame.draw.line(screen,color,(15,15),(width-15,height-15),15)    

            



draw_lines()    




player=2

game_over=False
while True:
    
    if not game_over:
        if player == 2:
                clec_row,clec_col = updata_and_returnmax()
                mark_square(clec_row,clec_col,2)
                if chick_win(player):
                    game_over=True
                player=1
        for event in pygame.event.get() :
            if event.type==pygame.QUIT:
                sys.exit()
            if  player ==1 and event.type==pygame.MOUSEBUTTONDOWN :
                mouseX=event.pos[0]
                mouseY=event.pos[1]

                clec_row=int(mouseY//200)
                clec_col=int(mouseX//200)
                print(clec_row)
                print(clec_col)
                if available_square(clec_row,clec_col):
                    if player==1:
                        mark_square(clec_row,clec_col,1)
                        if chick_win(player):
                            game_over=True
                        player=2

        
        draw_figures()
    
    pygame.display.update()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 0
# 1
# 1
# 1
# 2
# 1
